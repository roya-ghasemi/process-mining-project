# %%
import pandas as pd

# %%
import pm4py

# %%
pip install pm4py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# adjustText                    0.7.3
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# algo                          1.3.1
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# anyio                         3.5.0
# appdirs                       1.4.4
# arabic-reshaper               2.1.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# async-generator               1.10
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         22.2.0
# Automat                       20.2.0
# autopep8                      1.6.0
# ...

# %%
pip install pm4py[csv]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: pm4py 2.5.2 does not provide the extra 'csv'

# %%
print(pm4py.__version__)
# Out:
# 2.5.2

# %%
pip install pm4py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pm4py==2.2.15
# Out:
# ...
#   Attempting uninstall: pm4py
#     Found existing installation: pm4py 2.5.2
#     Uninstalling pm4py-2.5.2:
#       Successfully uninstalled pm4py-2.5.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pm4py==1.2.7
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2959 sha256=6e46b6c22e3a2692a9a5ca821613985952670c613c4bcbe20564b709a25d2413
#   Stored in directory: c:\users\ghasemi\appdata\local\pip\cache\wheels\f8\e0\3d\9d0c2020c44a519b9f02ab4fa6d2a4a996c98d79ab2f569fa1
# Successfully built sklearn
# ...
#   Attempting uninstall: pm4py
#     Found existing installation: pm4py 2.2.15
#     Uninstalling pm4py-2.2.15:
#       Successfully uninstalled pm4py-2.2.15
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # کد های زیر فقط روی این ورژن از این کتابخانه جواب میدهد
# # install_pm4py(version = "1.2.7")

# %%
from pm4py.objects.log.importer.csv import factory as csv_importer

# %%
from pm4py.algo.discovery.alpha import factory as alpha_miner

# %%
from pm4py.visualization.petrinet import factory as pn_vis_factory

# %%
from pm4py.visualization.process_tree import factory as pt_vis_factory

# %%
from pm4py.visualization.heuristics_net import factory as hn_vis_factory

# %%
event_log= csv_importer.import_event_log("DatasetProcessMining.csv")

# %%
pip install pm4py --upgrade
# Out:
# ...
#
# ...
#   Using cached pm4py-2.5.2-py3-none-any.whl (1.6 MB)
# ...
#   Attempting uninstall: pm4py
#     Found existing installation: pm4py 1.2.7
#     Uninstalling pm4py-1.2.7:
#       Successfully uninstalled pm4py-1.2.7
# ...

# %%
petri_net, initial_marking, final_marking = alpha_miner.apply(event_log, parameters={
    pm4py.util.constants.PARAMETER_CONSTANT_ACTIVITY_KEY: 'Activity',
    pm4py.util.constants.PARAMETER_CONSTANT_CASEID_KEY: 'CaseID'
})

# %%
pip install graphviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pm4py.visualization.petrinet import factory as pn_vis_factory

# %%
from pm4py.objects.petri_net.importer import importer as pnml_importer

# %%
import os

# %%
os.environ["PATH"] += os.pathsep + 'C:/Users/Ghasemi/.conda/'

# %%
gviz = pn_vis_factory.apply(petri_net, initial_marking, final_marking)
pn_vis_factory.view(gviz)
# Out:
# ---------------------------------------------------------------------------
#
# FileNotFoundError                         Traceback (most recent call last)
#
# File ~\anaconda3\lib\site-packages\graphviz\backend\execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#
#      80     else:
#
# ---> 81         proc = subprocess.run(cmd, **kwargs)
#
#      82 except OSError as e:
#
#
#
# File ~\anaconda3\lib\subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#
#     503     kwargs['stderr'] = PIPE
#
# --> 505 with Popen(*popenargs, **kwargs) as process:
#
#     506     try:
#
#
#
# File ~\anaconda3\lib\subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#
# ...
